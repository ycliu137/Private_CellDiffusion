# %%
import scanpy as sc
import anndata as ad
from scib_metrics.benchmark import Benchmarker
from scib_metrics.benchmark import BatchCorrection

import pandas as pd
import numpy as np
import pickle

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)

# %%
PATH = '/projectnb/czproj/Algorithms/ycliu/Pan_proj/outputs/inte_outputs/BMMC/'

path1 = '/projectnb/czproj/Algorithms/ycliu/scDiffusion/outputs/inte_outputs/BMMC/'

# %%
adata = sc.read_h5ad(PATH + 'scDiffusion_integration_logDif.h5ad')

adata
# Out:
# AnnData object with n_obs × n_vars = 30669 × 2000
#     obs: 'batch', 'labels', 'incoming_counts', 'outgoing_counts'
#     var: 'gene_id', 'gene_symbols', 'feature_types', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'batch_colors', 'gnd_state_dict', 'gnd_steps_data', 'gnd_steps_umap', 'graph_diffusion_args', 'hvg', 'integration_edge_index', 'integration_loss_dict_index', 'integration_loss_edge_index_dict', 'labels_colors', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_dif', 'X_fae', 'X_ho', 'X_ho_umap', 'X_umap', 'node_batch_mt'
#     obsp: 'connectivities', 'distances'

# %%
adata_Harmony = sc.read_h5ad(path1 + 'Harmony_integration.h5ad')

adata_Harmony
# Out:
# AnnData object with n_obs × n_vars = 30669 × 2000
#     obs: 'batch', 'labels'
#     var: 'gene_id', 'gene_symbols', 'feature_types', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'batch_colors', 'hvg', 'labels_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obsm['scDiffusion'] = adata.obsm['X_dif']

adata.obsm['Harmony'] = adata_Harmony.obsm['X_pca_harmony']

adata.obsm['Unintegrated'] = adata_Harmony.obsm['X_pca']

# %%
batch_corr = BatchCorrection(pcr_comparison=False)

def evaluate_integration(adata, batch_corr=batch_corr):
    bm = Benchmarker(
        adata,
        batch_key="batch",
        label_key="labels",
        embedding_obsm_keys=['scDiffusion', 'Harmony', 'Unintegrated'],
    
        pre_integrated_embedding_obsm_key='Unintegrated',
        batch_correction_metrics=batch_corr,
        n_jobs=1,
    )
    bm.benchmark()
    
    return bm

# %%
bm = evaluate_integration(adata)
# Out:
# Computing neighbors: 100%|██████████| 3/3 [01:19<00:00, 26.55s/it]
# Embeddings:   0%|          | 0/3 [00:00<?, ?it/s]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:42<06:26, 42.94s/it, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:42<06:26, 42.94s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [01:32<06:14, 46.81s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [01:32<06:14, 46.81s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [02:10<04:58, 42.62s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [02:10<04:58, 42.62s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [02:11<02:37, 26.21s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [02:11<02:37, 26.21s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [02:22<01:44, 20.80s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [02:22<01:44, 20.80s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [02:22<00:55, 13.85s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [02:22<00:55, 13.85s/it, Batch correction: kbet_per_label]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     gdT CD158b+ consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|███████   | 7/10 [03:19<01:24, 28.04s/it, Batch correction: kbet_per_label]
# Metrics:  70%|███████   | 7/10 [03:19<01:24, 28.04s/it, Batch correction: graph_connectivity]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  33%|███▎      | 1/3 [03:20<06:40, 200.22s/it]tch correction: graph_connectivity]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:35<05:15, 35.06s/it, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:35<05:15, 35.06s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:51<03:11, 23.92s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:51<03:11, 23.92s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [01:30<03:36, 30.99s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [01:30<03:36, 30.99s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [01:30<01:53, 18.84s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [01:30<01:53, 18.84s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [01:33<01:04, 12.96s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [01:33<01:04, 12.96s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [01:33<00:34,  8.62s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [01:33<00:34,  8.62s/it, Batch correction: kbet_per_label]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     gdT CD158b+ consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|███████   | 7/10 [01:52<00:35, 11.88s/it, Batch correction: kbet_per_label]
# Metrics:  70%|███████   | 7/10 [01:52<00:35, 11.88s/it, Batch correction: graph_connectivity]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  67%|██████▋   | 2/3 [05:12<02:28, 148.48s/it]tch correction: graph_connectivity]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:36<05:26, 36.24s/it, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:36<05:26, 36.24s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:51<03:13, 24.13s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:51<03:13, 24.13s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [01:28<03:28, 29.77s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [01:28<03:28, 29.77s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [01:28<01:48, 18.10s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [01:28<01:48, 18.10s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [01:30<01:02, 12.43s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [01:30<01:02, 12.43s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [01:31<00:33,  8.27s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [01:31<00:33,  8.27s/it, Batch correction: kbet_per_label]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     gdT CD158b+ consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|███████   | 7/10 [01:49<00:34, 11.65s/it, Batch correction: kbet_per_label]
# Metrics:  70%|███████   | 7/10 [01:49<00:34, 11.65s/it, Batch correction: graph_connectivity]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings: 100%|██████████| 3/3 [07:02<00:00, 140.80s/it]tch correction: graph_connectivity]

# %%
bm.plot_results_table(min_max_scale=False)

# %%
bm.plot_results_table(min_max_scale=False)
