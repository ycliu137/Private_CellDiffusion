# %%
import scanpy as sc
import anndata as ad
from scib_metrics.benchmark import Benchmarker
from scib_metrics.benchmark import BatchCorrection

import pandas as pd
import numpy as np
import pickle

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)

# %%
PATH = '/projectnb/czproj/Algorithms/ycliu/Pan_proj/outputs/inte_outputs/PBMC23K_rm100pct/'

path1 = '/projectnb/czproj/Algorithms/ycliu/scDiffusion/outputs/inte_outputs/PBMC23K_rm100pct/'

# %%
adata = sc.read_h5ad(PATH + 'scDiffusion_integration.h5ad')

adata
# Out:
# AnnData object with n_obs × n_vars = 21617 × 2000
#     obs: 'batch', 'labels', 'isolation', 'incoming_counts', 'outgoing_counts'
#     var: 'gene_ids', 'gene_symbols', 'feature_types', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'batch_colors', 'gnd_state_dict', 'gnd_steps_data', 'hvg', 'integration_edge_index', 'integration_loss_dict_index', 'integration_loss_edge_index_dict', 'isolation_colors', 'labels_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_dif', 'X_fae', 'X_pca', 'X_umap', 'node_batch_isolation', 'node_batch_mt'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata_Harmony = sc.read_h5ad(path1 + 'Harmony_integration.h5ad')

#adata_Harmony = adata_Harmony[adata_Harmony.obs['batch'].isin(['P8_0', 'P8_3'])]

adata_Harmony
# Out:
# AnnData object with n_obs × n_vars = 21617 × 2000
#     obs: 'batch', 'labels'
#     var: 'gene_ids', 'gene_symbols', 'feature_types', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'batch_colors', 'hvg', 'labels_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obsm['scDiffusion'] = adata.obsm['X_dif']

adata.obsm['Harmony'] = adata_Harmony.obsm['X_pca_harmony']

adata.obsm['Unintegrated'] = adata_Harmony.obsm['X_pca']

# %%
batch_corr = BatchCorrection(pcr_comparison=False)

def evaluate_integration(adata, batch_corr=batch_corr):
    bm = Benchmarker(
        adata,
        batch_key="batch",
        label_key="labels",
        embedding_obsm_keys=['scDiffusion', 'Harmony', 'Unintegrated'],
    
        pre_integrated_embedding_obsm_key='Unintegrated',
        batch_correction_metrics=batch_corr,
        n_jobs=1,
    )
    bm.benchmark()
    
    return bm

# %%
bm = evaluate_integration(adata)
# Out:
# Computing neighbors: 100%|██████████| 3/3 [00:47<00:00, 15.89s/it]
# Embeddings:   0%|          | 0/3 [00:00<?, ?it/s]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:16<02:30, 16.69s/it, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:16<02:30, 16.69s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:25<01:37, 12.17s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:25<01:37, 12.17s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [00:45<01:49, 15.60s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [00:45<01:49, 15.60s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [00:45<00:56,  9.50s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [00:45<00:56,  9.50s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [00:48<00:35,  7.12s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [00:48<00:35,  7.12s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [00:48<00:18,  4.74s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [00:48<00:18,  4.74s/it, Batch correction: kbet_per_label]
# INFO     ASDC consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     CD4 Proliferating consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     Eryth consists of a single batch or is too small. Skip.
# INFO     ILC consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     cDC1 consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|███████   | 7/10 [01:01<00:22,  7.49s/it, Batch correction: kbet_per_label]
# Metrics:  70%|███████   | 7/10 [01:01<00:22,  7.49s/it, Batch correction: graph_connectivity]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
# Embeddings:  33%|███▎      | 1/3 [01:01<02:03, 61.77s/it]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:21<03:11, 21.27s/it, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:21<03:11, 21.27s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:30<01:51, 13.93s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:30<01:51, 13.93s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [00:51<02:00, 17.19s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [00:51<02:00, 17.19s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [00:51<01:02, 10.46s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [00:51<01:02, 10.46s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [00:53<00:38,  7.63s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [00:53<00:38,  7.63s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [00:54<00:20,  5.08s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [00:54<00:20,  5.08s/it, Batch correction: kbet_per_label]
# INFO     ASDC consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     CD4 Proliferating consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     Eryth consists of a single batch or is too small. Skip.
# INFO     ILC consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     cDC1 consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|███████   | 7/10 [01:06<00:22,  7.35s/it, Batch correction: kbet_per_label]
# Metrics:  70%|███████   | 7/10 [01:06<00:22,  7.35s/it, Batch correction: graph_connectivity]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
# Embeddings:  67%|██████▋   | 2/3 [02:07<01:04, 64.33s/it]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:14<02:14, 14.98s/it, Bio conservation: isolated_labels]
# Metrics:  10%|█         | 1/10 [00:14<02:14, 14.98s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:23<01:31, 11.41s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  20%|██        | 2/10 [00:23<01:31, 11.41s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [00:39<01:34, 13.54s/it, Bio conservation: silhouette_label]
# Metrics:  30%|███       | 3/10 [00:39<01:34, 13.54s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [00:40<00:49,  8.25s/it, Bio conservation: clisi_knn]
# Metrics:  40%|████      | 4/10 [00:40<00:49,  8.25s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [00:42<00:30,  6.16s/it, Batch correction: silhouette_batch]
# Metrics:  50%|█████     | 5/10 [00:42<00:30,  6.16s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [00:42<00:16,  4.11s/it, Batch correction: ilisi_knn]
# Metrics:  60%|██████    | 6/10 [00:42<00:16,  4.11s/it, Batch correction: kbet_per_label]
# INFO     ASDC consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     CD4 Proliferating consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     Eryth consists of a single batch or is too small. Skip.
# INFO     ILC consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     cDC1 consists of a single batch or is too small. Skip.
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|███████   | 7/10 [00:54<00:19,  6.66s/it, Batch correction: kbet_per_label]
# Metrics:  70%|███████   | 7/10 [00:54<00:19,  6.66s/it, Batch correction: graph_connectivity]/projectnb/czproj/ycliu137/.conda/envs/scanpy_env/lib/python3.9/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
# Embeddings: 100%|██████████| 3/3 [03:02<00:00, 60.86s/it]

# %%
bm.plot_results_table(min_max_scale=False)
